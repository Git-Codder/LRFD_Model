# %%
import os
from PIL import Image

info = []
for root, __, files in os.walk("/home/kira/B. Tech project/originalPics"):
  for f in files:
      if f.endswith(".jpg"):
         info.append(os.path.join(root, f))
         
len(info)
# Out:
# 28204

# %%
import cv2

# for i in range(5000):
#     x = info[i].split("/")
#     x = x[len(x)-1].split(".")
#     name = x[len(x)-2] + "_" + str(i)
#     img = cv2.imread(info[i])
#     bigger = cv2.resize(img, (64, 64))
#     cv2.imwrite(os.path.join('resized', 'images', f'{name}.jpg'), bigger)
#     print(str(i) + " image resized : " + info[i])

# %%
# pip install mtcnn
# Out:
# /bin/bash: /home/kira/\/envs/my_env_dl/lib/python3.8/site-packages/cv2/../../../../lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
#      |████████████████████████████████| 2.3 MB 6.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 60.5 MB 4.6 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 1.6 MB 13.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 16.9 MB 11.9 MB/s eta 0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.16.6
#     Uninstalling numpy-1.16.6:
#       Successfully uninstalled numpy-1.16.6
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
info_1 = []
for root, __, files in os.walk("/home/kira/B. Tech project/resized/labels"):
  for f in files:
      if f.endswith(".json"):
         info_1.append(os.path.join(root, f))
         
len(info_1)
# Out:
# 3650

# %%
info_1[0]
# Out:
# '/home/kira/B. Tech project/resized/labels/img_167_1554.json'

# %%
# !touch "/home/kira/B. Tech project/resized/x.json"

# %%
labeled_info = []

# %%
import tensorflow as tf
from mtcnn import MTCNN
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
# detector = MTCNN()
# i = 0
# !mkdir "/home/kira/B. Tech project/resized/img"
# !mkdir "/home/kira/B. Tech project/resized/labels"
# !mkdir "/home/kira/B. Tech project/resized/noface"

# for i in range(len(info_1)):
#     path = '"' + info_1[i] + '"'
#     x = info_1[i].split("/")
#     x = x[len(x)-1].split(".")
#     name = x[len(x)-2]
#     img1 = cv2.cvtColor(cv2.imread(info_1[i]), cv2.COLOR_BGR2RGB)
#     temp = detector.detect_faces(img1)
#     if(len(temp) == 1):
        
#         !mv $path "/home/kira/B. Tech project/resized/img"
#         cord = temp[0]['box']
#         obj = []
#         obj.append({
#             "label":'face',
#             "points":[[cord[0], cord[1]], [cord[0]+cord[2], cord[1]+cord[3]]]
#         })
#         tmp = "/home/kira/B. Tech project/resized/labels/" + name + ".json"
#         with open(tmp, "w") as file:
#               json.dump([ob for ob in obj], file)
        
#     elif(len(temp) == 0):
#         !mv $path "/home/kira/B. Tech project/resized/noface"
#     if(i%500 == 0):
#         print(i)
# Out:
# ...
# 1/1 [==============================] - 0s 122ms/step
# 0
# ...
# 1/1 [==============================] - 0s 25ms/step
# ...
# ...
# 1/1 [==============================] - 0s 21ms/step

# %%
import pandas as pd
cnt = 0
for i in range(len(info_1)):
    labeled_info = pd.read_json(info_1[i])
    cnt += (labeled_info['points'].isnull().sum())
#     if(labeled_info['points'].iloc[0] == None):
#         cnt+=1
print(len(info_1)cnt)
# Out:
# 3650
